# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df.shape
# Out:
# (1340, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          1340 non-null   int64
#  1   PatientID      1340 non-null   int64
#  2   age            1335 non-null   float64
#  3   gender         1340 non-null   object
#  4   bmi            1340 non-null   float64
#  5   bloodpressure  1340 non-null   int64
#  6   diabetic       1340 non-null   object
#  7   children       1340 non-null   int64
#  8   smoker         1340 non-null   object
#  9   region         1337 non-null   object
#  10  claim          1340 non-null   float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 115.3+ KB

# %%
df.shape
# Out:
# (1340, 11)

# %%
df.dtypes
# Out:
# index              int64
# PatientID          int64
# age              float64
# gender            object
# bmi              float64
# bloodpressure      int64
# diabetic          object
# children           int64
# smoker            object
# region            object
# claim            float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(2)
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51

# %%
df.isnull().sum()
# Out:
# index            0
# PatientID        0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64

# %%
null_wert = pd.concat([
    df["age"],
    df["region"]
],axis=1)

# %%
null_wert.head()
# Out:
#     age     region
# 0  39.0  southeast
# 1  24.0  southeast
# 2   NaN  southeast
# 3   NaN  northwest
# 4   NaN  northwest

# %%
df.describe()
# Out:
#              index    PatientID          age          bmi  bloodpressure  \
# count  1340.000000  1340.000000  1335.000000  1340.000000    1340.000000
# mean    669.500000   670.500000    38.078652    30.668955      94.157463
# std     386.968991   386.968991    11.102924     6.106735      11.434712
# min       0.000000     1.000000    18.000000    16.000000      80.000000
# 25%     334.750000   335.750000    29.000000    26.275000      86.000000
# 50%     669.500000   670.500000    38.000000    30.400000      92.000000
# 75%    1004.250000  1005.250000    47.000000    34.700000      99.000000
# max    1339.000000  1340.000000    60.000000    53.100000     140.000000
#
#           children         claim
# count  1340.000000   1340.000000
# mean      1.093284  13252.745642
# std       1.205334  12109.609288
# min       0.000000   1121.870000
# 25%       0.000000   4719.685000
# 50%       1.000000   9369.615000
# 75%       2.000000  16604.305000
# max       5.000000  63770.430000

# %%
for col in df.columns:
    print(f"*****{col}*****")
    print(df[col].value_counts())
    print("****************")
# Out:
# *****index*****
# 0       1
# 900     1
# 898     1
# 897     1
# 896     1
#        ..
# 445     1
# 444     1
# 443     1
# 442     1
# 1339    1
# Name: index, Length: 1340, dtype: int64
# ****************
# *****PatientID*****
# 1       1
# 901     1
# 899     1
# 898     1
# 897     1
#        ..
# 446     1
# 445     1
# 444     1
# 443     1
# 1340    1
# Name: PatientID, Length: 1340, dtype: int64
# ****************
# *****age*****
# 43.0    50
# 26.0    47
# 46.0    44
# 30.0    44
# 32.0    44
# 40.0    42
# 27.0    41
# 37.0    41
# 48.0    40
# 45.0    40
# 29.0    39
# 34.0    39
# 49.0    38
# 31.0    38
# 42.0    37
# 47.0    37
# 36.0    37
# 35.0    36
# 28.0    36
# 44.0    35
# 33.0    35
# 50.0    32
# 38.0    32
# 25.0    32
# 19.0    29
# 23.0    28
# 55.0    26
# 20.0    26
# 39.0    26
# 41.0    24
# 22.0    24
# 59.0    22
# 57.0    21
# 60.0    21
# 21.0    18
# 52.0    18
# 56.0    18
# 54.0    17
# 51.0    17
# 58.0    17
# 24.0    16
# 18.0    16
# 53.0    15
# Name: age, dtype: int64
# ****************
# *****gender*****
# male      678
# female    662
# Name: gender, dtype: int64
# ****************
# *****bmi*****
# 33.3    17
# 27.6    17
# 28.9    16
# 32.3    15
# 29.8    14
#         ..
# 17.9     1
# 21.0     1
# 50.4     1
# 49.1     1
# 47.4     1
# Name: bmi, Length: 275, dtype: int64
# ****************
# *****bloodpressure*****
# 91     62
# 80     59
# 88     58
# 89     58
# 81     58
#        ..
# 138     1
# 116     1
# 134     1
# 121     1
# 133     1
# Name: bloodpressure, Length: 61, dtype: int64
# ****************
# *****diabetic*****
# No     698
# Yes    642
# Name: diabetic, dtype: int64
# ****************
# *****children*****
# 0    576
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
# ****************
# *****smoker*****
# No     1066
# Yes     274
# Name: smoker, dtype: int64
# ****************
# *****region*****
# southeast    443
# northwest    349
# southwest    314
# northeast    231
# Name: region, dtype: int64
# ****************
# *****claim*****
# 1639.56     2
# 1704.57     2
# 1149.40     2
# 1121.87     1
# 12797.21    1
#            ..
# 6282.24     1
# 6272.48     1
# 6250.44     1
# 6238.30     1
# 63770.43    1
# Name: claim, Length: 1337, dtype: int64
# ****************

# %%
for col in df.columns:
    print(f"*****{col}*****")
    print(df[col].unique())
    print("****************")
# Out:
# *****index*****
# [   0    1    2 ... 1337 1338 1339]
# ****************
# *****PatientID*****
# [   1    2    3 ... 1338 1339 1340]
# ****************
# *****age*****
# [39. 24. nan 19. 20. 30. 36. 37. 32. 40. 35. 41. 49. 48. 45. 34. 18. 42.
#  50. 23. 58. 29. 21. 52. 43. 47. 28. 44. 31. 51. 60. 27. 26. 22. 38. 53.
#  54. 33. 59. 55. 46. 57. 25. 56.]
# ****************
# *****gender*****
# ['male' 'female']
# ****************
# *****bmi*****
# [23.2 30.1 33.3 33.7 34.1 34.4 37.3 41.1 43.  53.1 19.8 20.3 20.7 27.6
#  28.7 30.4 35.4 31.1 35.5 36.9 20.8 26.7 17.5 31.4 20.4 21.8 22.6 38.2
#  38.3 25.2 25.6 39.2 39.8 40.3 27.8 30.6 26.8 33.8 39.5 16.  21.5 23.
#  23.1 23.8 25.5 26.1 23.3 28.5 29.4 30.  35.2 17.8 18.6 20.6 24.7 28.9
#  29.8 32.9 40.5 29.7 26.5 32.6 20.9 24.6 41.9 28.4 29.6 31.5 33.  29.
#  31.3 22.  27.9 23.4 25.8 29.3 32.  35.9 34.6 34.9 32.1 26.  22.3 27.4
#  22.5 30.5 36.6 25.7 37.4 24.3 27.1 28.1 28.8 36.  25.1 26.3 28.2 24.1
#  30.3 31.9 33.2 35.6 40.2 31.7 26.2 23.7 32.4 24.5 35.7 50.4 27.7 34.
#  32.7 20.2 17.4 22.1 26.4 28.3 17.7 38.1 31.8 39.6 24.2 29.9 27.2 29.5
#  29.2 46.5 34.5 25.3 26.6 30.9 16.8 33.1 33.4 22.2 21.9 23.5 28.6 42.1
#  37.1 33.9 25.9 38.7 42.4 34.8 38.9 32.5 39.3 33.6 45.9 17.3 29.1 37.6
#  34.2 31.2 44.2 20.  21.3 35.8 27.  26.9 38.4 35.  21.4 34.7 42.9 20.5
#  30.2 30.8 27.3 37.2 22.9 43.1 38.6 18.5 18.9 37.  31.6 23.6 27.5 23.9
#  17.9 38.8 31.  32.8 37.7 41.7 19.9 41.8 42.7 43.3 36.2 34.3 24.9 30.7
#  28.  38.  32.3 45.4 40.6 37.9 36.3 25.  41.2 21.1 19.  32.2 36.1 19.5
#  22.7 35.3 25.4 41.3 22.8 47.5 24.  39.4 19.6 45.3 19.2 40.4 43.9 44.8
#  36.7 37.5 22.4 39.7 48.1 24.8 41.5 44.7 46.1 18.1 40.  47.7 21.6 40.7
#  18.3 21.  42.5 49.1 36.4 24.4 46.7 40.9 43.7 39.1 20.1 36.5 33.5 40.8
#  43.4 46.8 35.1 39.9 44.  21.7 36.8 17.2 18.  19.3 19.1 18.7 41.4 42.2
#  37.8 44.9 42.8 45.5 39.  52.6 46.2 47.6 47.4]
# ****************
# *****bloodpressure*****
# [ 91  87  82  80 100  96  86  97  88  90  81  84  85  93  98  83  94  89
#   99  95  92 106 105 103 102 109 110 101 104 107 108 128 115 135 126 137
#  119 123 118 130 113 139 114 111 132 122 129 136 125 124 140 117 131 127
#  112 138 116 120 134 121 133]
# ****************
# *****diabetic*****
# ['Yes' 'No']
# ****************
# *****children*****
# [0 1 2 3 4 5]
# ****************
# *****smoker*****
# ['No' 'Yes']
# ****************
# *****region*****
# ['southeast' 'northwest' nan 'southwest' 'northeast']
# ****************
# *****claim*****
# [ 1121.87  1131.51  1135.94 ... 60021.4  62592.87 63770.43]
# ****************

# %%
for col in df.columns:
    print(f"*****{col}*****")
    print(df[col].nunique())
    print("****************")
# Out:
# *****index*****
# 1340
# ****************
# *****PatientID*****
# 1340
# ****************
# *****age*****
# 43
# ****************
# *****gender*****
# 2
# ****************
# *****bmi*****
# 275
# ****************
# *****bloodpressure*****
# 61
# ****************
# *****diabetic*****
# 2
# ****************
# *****children*****
# 6
# ****************
# *****smoker*****
# 2
# ****************
# *****region*****
# 4
# ****************
# *****claim*****
# 1337
# ****************

# %%
rounded_mean_age = round(np.mean(df["age"]), 2)
rounded_mean_age
# Out:
# 38.08

# %%
df["age"].fillna(rounded_mean_age, inplace=True)

# %%
df["region"].head(2)
# Out:
# 0    southeast
# 1    southeast
# Name: region, dtype: object

# %%
df["region"].fillna(df["region"].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# index            0
# PatientID        0
# age              0
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           0
# claim            0
# dtype: int64

# %%
df.head()
# Out:
#    index  PatientID    age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.00   male  23.2             91      Yes         0
# 1      1          2  24.00   male  30.1             87       No         0
# 2      2          3  38.08   male  33.3             82      Yes         0
# 3      3          4  38.08   male  33.7             80       No         0
# 4      4          5  38.08   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df.describe()
# Out:
#              index    PatientID          age          bmi  bloodpressure  \
# count  1340.000000  1340.000000  1340.000000  1340.000000    1340.000000
# mean    669.500000   670.500000    38.078657    30.668955      94.157463
# std     386.968991   386.968991    11.082175     6.106735      11.434712
# min       0.000000     1.000000    18.000000    16.000000      80.000000
# 25%     334.750000   335.750000    29.000000    26.275000      86.000000
# 50%     669.500000   670.500000    38.000000    30.400000      92.000000
# 75%    1004.250000  1005.250000    47.000000    34.700000      99.000000
# max    1339.000000  1340.000000    60.000000    53.100000     140.000000
#
#           children         claim
# count  1340.000000   1340.000000
# mean      1.093284  13252.745642
# std       1.205334  12109.609288
# min       0.000000   1121.870000
# 25%       0.000000   4719.685000
# 50%       1.000000   9369.615000
# 75%       2.000000  16604.305000
# max       5.000000  63770.430000

# %%
df.head()
# Out:
#    index  PatientID    age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.00   male  23.2             91      Yes         0
# 1      1          2  24.00   male  30.1             87       No         0
# 2      2          3  38.08   male  33.3             82      Yes         0
# 3      3          4  38.08   male  33.7             80       No         0
# 4      4          5  38.08   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df.drop("PatientID", axis=1, inplace=True)

# %%
df.head()
# Out:
#    index    age gender   bmi  bloodpressure diabetic  children smoker  \
# 0      0  39.00   male  23.2             91      Yes         0     No
# 1      1  24.00   male  30.1             87       No         0     No
# 2      2  38.08   male  33.3             82      Yes         0     No
# 3      3  38.08   male  33.7             80       No         0     No
# 4      4  38.08   male  34.1            100       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51
# 2  southeast  1135.94
# 3  northwest  1136.40
# 4  northwest  1137.01

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
count_data = df[["gender","diabetic", "children", "smoker"]]

# %%
for col in count_data.columns:
    plt.figure(figsize=(10,6))
    sns.countplot(x=col, data=count_data, hue=df["region"])
    plt.title(f"The count of {col} by region", fontsize=15)
    plt.show()

# %%
for col in df.columns:
    if df[col].dtype != "object" and col !="index" :
        plt.figure(figsize=(10,6))
        sns.histplot(df[col], kde=True)
        plt.title(f"The distribution of {col}", fontsize=15)
        plt.show()

# %%
count_data.value_counts()
# Out:
# gender  diabetic  children  smoker
# female  No        0         No        119
#         Yes       0         No        117
# male    No        0         No        114
#         Yes       0         No        111
# female  No        1         No         77
# male    No        1         No         71
#         Yes       1         No         59
# female  Yes       1         No         56
#                   2         No         51
# male    No        2         No         46
# female  No        2         No         46
# male    Yes       2         No         42
#         No        0         Yes        35
#                   3         No         33
# female  Yes       3         No         32
#         No        3         No         31
#         Yes       0         Yes        29
# male    Yes       0         Yes        27
# female  No        0         Yes        24
# male    Yes       3         No         22
#         No        1         Yes        20
#         Yes       2         Yes        18
#                   1         Yes        16
#         No        2         Yes        15
# female  Yes       1         Yes        14
# male    Yes       3         Yes        13
# female  No        2         Yes        13
# male    No        3         Yes        12
# female  No        1         Yes        11
#         Yes       2         Yes         9
#                   3         Yes         7
#         No        3         Yes         7
# male    No        4         No          6
#                   5         No          6
# female  No        4         No          6
#         Yes       4         No          5
#         No        5         No          5
# male    Yes       4         No          5
#                   5         No          4
# female  Yes       5         No          2
# male    Yes       4         Yes         2
#         No        4         Yes         1
# female  Yes       5         Yes         1
# dtype: int64

# %%
for col in df.columns:
    if df[col].dtype != "object" and col !="index" :
        plt.figure(figsize=(10,6))
        sns.boxplot(x=col, data=df)
        plt.title(f"The distribution of {col}", fontsize=15)
        plt.show()

# %%
for col in count_data.columns:
    plt.figure(figsize=(10, 10))
    plt.pie(df[col].value_counts(), labels=df[col].value_counts().index, autopct="%.1f%%")
    plt.title(f"The count of {col}", fontsize=15)

# %%
df.head(2)
# Out:
#    index   age gender   bmi  bloodpressure diabetic  children smoker  \
# 0      0  39.0   male  23.2             91      Yes         0     No
# 1      1  24.0   male  30.1             87       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51

# %%
sns.pairplot(df, hue="region")

# %%
df.corr()
# Out:
#                   index       age       bmi  bloodpressure  children     claim
# index          1.000000 -0.007451  0.115129       0.450602  0.128104  0.879268
# age           -0.007451  1.000000 -0.041919      -0.060247 -0.025508 -0.027857
# bmi            0.115129 -0.041919  1.000000       0.143544  0.012092  0.197401
# bloodpressure  0.450602 -0.060247  0.143544       1.000000 -0.031682  0.531341
# children       0.128104 -0.025508  0.012092      -0.031682  1.000000  0.069233
# claim          0.879268 -0.027857  0.197401       0.531341  0.069233  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="viridis")
plt.title("The correlation between the features", fontsize=15)
plt.show()

# %%
df_clean = df.copy()

# %%
df_clean.head()
# Out:
#    index    age gender   bmi  bloodpressure diabetic  children smoker  \
# 0      0  39.00   male  23.2             91      Yes         0     No
# 1      1  24.00   male  30.1             87       No         0     No
# 2      2  38.08   male  33.3             82      Yes         0     No
# 3      3  38.08   male  33.7             80       No         0     No
# 4      4  38.08   male  34.1            100       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51
# 2  southeast  1135.94
# 3  northwest  1136.40
# 4  northwest  1137.01

# %%
df_clean.isnull().sum()
# Out:
# index            0
# age              0
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           0
# claim            0
# dtype: int64

# %%
df_clean.to_csv('df_clean.csv', index=False)

# %%
csv_clean = pd.read_csv("df_clean.csv")

# %%
csv_clean.head()
# Out:
#    index    age gender   bmi  bloodpressure diabetic  children smoker  \
# 0      0  39.00   male  23.2             91      Yes         0     No
# 1      1  24.00   male  30.1             87       No         0     No
# 2      2  38.08   male  33.3             82      Yes         0     No
# 3      3  38.08   male  33.7             80       No         0     No
# 4      4  38.08   male  34.1            100       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51
# 2  southeast  1135.94
# 3  northwest  1136.40
# 4  northwest  1137.01
